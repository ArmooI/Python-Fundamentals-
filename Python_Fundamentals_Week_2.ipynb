# %% [markdown]
# ![Screenshot 2024-07-08 112907.png](attachment:80220983-b9b6-465d-8164-13dd1ab15f77.png)

# %% [markdown]
# Key Concepts covered in this week are as follows:
#
# * **Containers: List, Tuples and Sets**
#
# * **Iterations (for and while loops)**
#
# * **Conditionals**
#
# * **Combining Conditionals**
#
# * **The if-elif-else statements**

# %% [markdown]
# # 1. Understanding Containers in Python

# %% [markdown]
# Containers are a fundamental concept in Python programming that allow you to **store and organize data effectively**. These containers help you keep your data organized and make it easier to work with different types of data in Python. Python offers several built-in container types, such as **lists, tuples, sets, and dictionaries**, each with distinct characteristics and use cases. These containers are commonly referred to as **data structures**.

# %% [markdown]
# ### 1.1 What are Data Structures?

# %% [markdown]
# In computer programming, data structures are systematic methods used to store and organize data in computer memory, aiming to optimize operations like access, insertion, and modification for efficient data manipulation.
#
# In Python, data structures are implemented through a variety of built-in data types and modules, providing developers with a rich set of tools to efficiently manage and manipulate data. Lists, tuples, sets, and dictionaries are fundamental data structures in Python, each serving different purposes.

# %% [markdown]
# # 2. Lists in Python

# %% [markdown]
# In Python, a list is a versatile container that **can store a collection of items**. These items can be of various types, including integers, strings, or a combination of both. **Lists are mutable**, meaning that they can be modified after they are created.
#
# Think of a list as a flexible container that **allows you to store multiple values within a single variable**. Unlike other variables that can only store a single value, lists can hold a sequence of elements, such as numbers and names, and can accommodate elements of different data types within the same list.

# %%
# To see the type of variable, use type()
# for instance, 

type(my_siblings) # this shows the type of data type of my variable (my_siblings)

friends = ('Dosty', 'Kwata', 'Sammy')
type(friends) # this shows that (friends have tuple data)
# Out:
# tuple

# %%
dir([]) # this shoes gives a detailed list of comands and attributes
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ### 2.1 Creating a List

# %% [markdown]
# To create a list, simply enclose its elements in **square brackets [ ]** and separate them with **commas**. Afterward, **assign the list to a variable**.

# %%
# Creating a list
# my_list = [element1, element2, element3, ...]

# lists must be created for variables. 

my_siblings = ['Adjoechie', 'Homa', 'Amichia', 'Kpanyi']

print(my_siblings)
# Out:
# ['Adjoechie', 'Homa', 'Amichia', 'Kpanyi']

# %% [markdown]
# **NOTE:** When creating a Python list, you can directly include integers, floats, and Booleans without quotes. However, **strings should be enclosed in either single or double quotes**.

# %% [markdown]
# #### Examples of valid Python lists

# %%
# A list of int
numbers = [1, 2, 3, 4, 5, 6, 7, 8] # this is a simple list of counting number 
print(numbers)

# A list of strings
my_siblings = ['Adjoechie', 'Homa', 'Amichia', 'Kpanyi']

#A mixed-type list
mixed_list = [1,2,3, 'Adjoechie', 'Homa', 2.25, 1.23, False]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# An Empty list
# this is a list that contains no elements.  eg, below
empty_list = []
print(empty_list)
# Out:
# []

# %%
# list()

# we can convert a tuple element into a list by using the list(). eg, below 

siblings = 'Adjoechie', 'Homa', 'Amichia', 'Kpanyi'
print(siblings)
type(siblings) # checking the type of the variable (siblings)
# Out:
# ('Adjoechie', 'Homa', 'Amichia', 'Kpanyi')
# tuple

# %%
siblings = 'Adjoechie', 'Homa', 'Amichia', 'Kpanyi'
len(siblings) # this counts the number of elements contained in a list
# Out:
# 4

# %%
# list constructor 
# we can convert the siblings variable to list by using the list constructor "list()"

siblings_list = list(siblings) # this is to convert the siblings to a list by creating a new variable 
print(siblings_list)
type(siblings_list) # checking the type for the newly created variable
# Out:
# ['Adjoechie', 'Homa', 'Amichia', 'Kpanyi']
# list

# %% [markdown]
# ### 2.2 Accessing List Elements

# %% [markdown]
# You can access elements in a list using **indexing**. Indexing refers to the process of accessing individual elements within a list **by their position or index number**. Each element in a list has a **unique position index, starting from 0**. By specifying the index number in *square brackets* **[ ]**, you can retrieve the value of a specific element in the list.

# %% [markdown]
# **NOTE:** In Python, **negative indices** are used to access elements from the end of the list, allowing you to retrieve elements from the list **in reverse order**.

# %%
# eg. 

mixed_list = [1,2,3, 'Adjoechie', 'Homa', 2.25, 1.23, False]
print(mixed_list[2]) # this prints the 2nd element in the list starting from 0
print(mixed_list[-4]) # this returns the 4 element in the list starting from the last element and counting backwards
# Out:
# 3
# Homa

# %%
# Example 1
# Out:
# True

# %%
# Example 2
# Out:
# 7.6

# %%
# Example 3  --- Using negative indexing
# Out:
# True

# %%
# Example 4
# Out:
# 7.6

# %% [markdown]
# ### 2.3 Modifying a List

# %% [markdown]
# In addition to accessing elements, you can also modify the contents of a list. **Lists are mutable**, meaning you can change, add, or remove elements after the list has been created. This flexibility makes lists a powerful and dynamic data structure in Python.
#
# To modify a specific element in a list, **you can use indexing to access the element and then assign a new value to it**.

# %%
# to change one of the elements in a list, we use. eg. to replace "3" with "Amichia", follow below 
mixed_list = [1,2,3, 'Adjoechie', 'Homa', 2.25, 1.23, False]

mixed_list[2] = "Amichia"
print(mixed_list)
# Out:
# [1, 2, 'Amichia', 'Adjoechie', 'Homa', 2.25, 1.23, False]

# %%
# change ife to Tana
# Out:
# ['Tana', 'Grace']

# %% [markdown]
# #### Adding a New Element to the List

# %% [markdown]
# You can add elements to the end of a list using the **append()** method. The *append()* method is a standard method in Python for adding a single element to the end of a list.

# %%
# using append - this is one method
# append Kpanyi to the list name

# we can add "Kpanyi" to the list of the variable mixed_list

mixed_list.append("Kpanyi")
print(mixed_list)
# Out:
# [1, 2, 'Amichia', 'Adjoechie', 'Homa', 2.25, 1.23, False, 'Kpanyi']

# %%
#extend is best to add multiple elements 
# using extend - this is another method
# extend the list by Ama, Egya Armoo

mixed_list.extend(["Patoo"]) # to add just one name 
mixed_list.extend(["Ama", "Egya Armoo"]) # use [] to specify the element to be added to the list
print(mixed_list)
# Out:
# [1, 2, 'Amichia', 'Egya Nda', 'Adjoechie', 'Homa', 2.25, 1.23, False, 'Kpanyi', 'Ama', 'Egya Armoo', 'P', 'a', 't', 'o', 'o', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo']

# %%
# append list with multiple values
# Out:
# ['Tana', 'Grace', 'Kwabena', 'Gideon', 'Daniel', ['Melisa', 'David']]

# %% [markdown]
# * **Question:  how can I add an element at a specific position?**

# %%
# Using insert() method
# example 1 

mixed_list.insert(3, "Egya Nda") # the "3" indicates the position at which the new element should be added and the new element must be in "" as shown by "Egya Nda"
print(mixed_list)
# Out:
# [1, 2, 'Amichia', 'Egya Nda', 'Egya Nda', 'Adjoechie', 'Homa', 2.25, 1.23, False, 'Kpanyi', 'Ama', 'Egya Armoo', 'P', 'a', 't', 'o', 'o', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo']

# %%
# example

# %% [markdown]
# #### Removing Elements from a List

# %% [markdown]
# To remove elements from a list, you can use the **remove()** method by specifying the value of the element you want to delete. Alternatively, you can use the **pop()** method to remove an element at a specific index.

# %%
# we can remove elements from a list by using variable.remove([])
#eg.

mixed_list.remove("1")
print(mixed_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 4
#       1 # we can remove elements from a list by using variable.remove([])
#       2 #eg.
# ----> 4 mixed_list.remove("1")
#       5 print(mixed_list)
#
# ValueError: list.remove(x): x not in list

# %%
# Example -- using copy()

# %%
# Example  -- using remove()
# Out:
# ['Tana', 'Grace', 'Christian', 'Kwabena', 'Gideon', ['Melisa', 'David']]

# %%
# Out:
# ['Tana', 'Grace', 'Christian', 'Kwabena', 'Gideon']

# %%
# Example  -- using pop()
# without specifying the index of the element you want to delete, variable.pop() will delete the last element in the list

mixed_list.pop()
print(mixed_list)
# Out:
# [1, 2, 'Amichia', 'Egya Nda', 'Egya Nda', 'Adjoechie', 'Homa', 2.25, 1.23, False, 'Kpanyi', 'Ama', 'Egya Armoo', 'P', 'a', 't', 'o', 'o', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo', 'Ama', 'Egya Armoo', 'Patoo', 'Ama']

# %%
# with index specification

mixed_list.pop(13) # this removes "p" as it is on the 13th position
print(mixed_list)
# Out:
# [1, 2, 'Amichia', 'Egya Nda', 'Egya Nda', 'Adjoechie', 'Homa', 2.25, 1.23, False, 'Kpanyi', 'Ama', 'Egya Armoo', 'o', 'o', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo', 'Patoo', 'Ama', 'Egya Armoo', 'Ama', 'Egya Armoo', 'Patoo', 'Ama']

# %%
# specifying the index --
# Out:
# 'Grace'

# %%
# Out:
# ['Tana', 'Christian', 'Kwabena']

# %% [markdown]
# ### 2.4 Slicing a List

# %% [markdown]
# Slicing a list in Python refers to the technique of **extracting a portion of a list to create a new list**. This is achieved by specifying a range of indices using the **colon (:) operator** within square brackets.

# %%
print(siblings)
# Out:
# ('Adjoechie', 'Homa', 'Amichia', 'Kpanyi')

# %%
# if I want the 3 element in the siblings list. I can use the index below
# important to note that the indexing starts numbering from 0 so the first element in the list has 0 index, second element has 1 index and so on
siblings[2] # this finds the 3rd element in the list 
siblings[3] # this finds the 4th element in the list
# Out:
# 'Kpanyi'

# %% [markdown]
# inserting elements into a list with indeces

# %%
# assume I want to insert the name "Ama" into the siblings list into the index 2

print(siblings)
# siblings.insert(2, 'Ama')
print(siblings)
# Out:
# ('Adjoechie', 'Homa', 'Amichia', 'Kpanyi')
# ('Adjoechie', 'Homa', 'Amichia', 'Kpanyi')

# %%
# Syntax
# new_slice = my_list[start_index:end_index]

# %% [markdown]
# **NOTE**: It's important to understand that in Python slicing, **the element at the end index is not included in the selected range**. For example, **my_list[0:3]** selects elements **starting from index 0 up to index 2** *(but not including index 3)*, meaning Python will only select the elements at **indices 0, 1, and 2**. This is important for understanding how slicing works in Python.

# %%
# List
# Out:
# ['Tana', 'Christian', 'Kwabena', 'Gideon', 'Prince', 'Frankline', 'Patricia']

# %%
# Example
# Out:
# ['Kwabena', 'Gideon', 'Prince']

# %% [markdown]
# #### Omitting Indices in Slicing

# %% [markdown]
# You can omit one or both indices when slicing. If the starting index is omitted, it defaults to **the beginning of the list**. If the ending index is omitted, it defaults to **the end of the list**.

# %%
#Example
# Out:
# ['Tana', 'Christian', 'Kwabena', 'Gideon', 'Prince', 'Frankline', 'Patricia']

# %%
# .copy()

# %% [markdown]
# #### Negative Indices in Slicing

# %% [markdown]
# You can also use negative indices to extract elements from the end of the list.

# %%
# Example 
# start : end : step
# Out:
# ['Patricia', 'Frankline', 'Prince', 'Gideon', 'Kwabena', 'Christian', 'Tana']

# %%
# reverse()
# Out:
# ['Patricia', 'Frankline', 'Prince', 'Gideon', 'Kwabena', 'Christian', 'Tana']

# %% [markdown]
# ### 2.5 Searching for List Elements

# %% [markdown]
# Python provides a convenient way to check if a specific element exists in a list using the **in** keyword. This keyword returns a Boolean value, indicating whether the specified element is present in the list or not.

# %%
# Using the membership operator   --- IN
# Out:
# False

# %%
# Out:
# True

# %%
# Using the membership operator   --- NOT IN
# Out:
# True

# %%
# Out:
# False

# %% [markdown]
# ### 2.6 Sorting List Elements
#
# The sort method sorts the list elements in ascending order by default.

# %%
# Out:
# ['Patricia', 'Frankline', 'Prince', 'Gideon', 'Kwabena', 'Christian', 'Tana']

# %%
# Example
# Out:
# ['Christian', 'Frankline', 'Gideon', 'Kwabena', 'Patricia', 'Prince', 'Tana']

# %%
# Out:
# [1, 2, 3, 4, 5]

# %%
# Example ---Sort in descending order
# Out:
# ['Tana', 'Prince', 'Patricia', 'Kwabena', 'Gideon', 'Frankline', 'Christian']

# %%
# To see all list methods
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# # 3. Tuples

# %% [markdown]
# A tuple is another type of container in Python. **It is mostly similar to a list**, but with a few differences. **Tuples are created with parentheses, and they are immutable**. This means that once a tuple is created, its elements cannot be changed or modified. This makes tuples suitable for situations where the data should remain constant throughout the program.

# %% [markdown]
# To create a tuple, use **parentheses ()** instead of square brackets, and separate the elements with commas. Assign the tuple to a variable.

# %% [markdown]
# # Creating a tuple
# my_tuple = (element1, element2, element3, ...)

# %% [markdown]
# **NOTE:** Elements within a tuple can be of different data types, and when including strings, they should be enclosed in either single or double quotes to ensure proper formatting and interpretation.

# %%
# Numerical
# Out:
# (7, 8, 9, 10)
# tuple

# %%
# Strings
# Out:
# ('Portia', 'Melisa', 'Christian', 'Tana')
# tuple

# %%
# Mixed Data types
# Out:
# (3, 6, 1.5, 'beetroot', 'banana', True)
# tuple

# %% [markdown]
# ### 3.2 Accessing Tuple Elements

# %% [markdown]
# Similar to lists, you can access elements in a tuple using indexing. Indexing starts from 0, and negative indices can be used to access elements from the end of the tuple.

# %%
# Example
# Out:
# 'beetroot'

# %%
# Out:
# 'beetroot'

# %%
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %% [markdown]
# ### 3.3 Searching for Tuple Elements

# %% [markdown]
# To check if a specific element exists in a tuple, you can use the **in** keyword, similar to lists.

# %%
# Using IN
# Out:
# False

# %%
# Out:
# True

# %%
# Using NOT IN
# Out:
# True

# %%
# Out:
# False

# %%
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\nanay\AppData\Local\Temp\ipykernel_12804\2100346995.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   'banana' is fruits_tuple
# False

# %%
# Out:
# False

# %% [markdown]
# # 4. Sets

# %% [markdown]
# In Python, a set is an **unordered collection of unique elements**. This means that **a set cannot contain duplicate values**, making it an ideal data structure when you need to store a collection of distinct items. Sets are mutable, allowing you to add or remove elements after creation.

# %% [markdown]
# ### 4.1 Creating a Set

# %% [markdown]
# To create a set, use **curly braces {}** or the **set()** constructor, and separate the elements with commas.

# %%
# Creating a set
# my_set = {element1, element2, element3, ...}

# # Creating a set using set() constructor
# my_set = set([element1, element2, element3, ...])

# %% [markdown]
# **NOTE**: Unlike lists and tuples, **sets do not support indexing** as they are unordered collections.

# %% [markdown]
# #### Examples of Sets

# %%
# Set of integers
# Out:
# {1, 3, 4, 7, 9}
# set

# %%
# Set of strings


# Mixed-type set
# Out:
# {'apple', 'banana', 'orange', 'avocado', 'pineapple'}
# {1.5, True, 3, 6, 'banana', 'beetroot'}
# set

# %%
# Call a variable

# %% [markdown]
# ### 4.2 Accessing Set Elements

# %% [markdown]
# Since sets are unordered, **they do not have indices**, and **you cannot access specific elements using indexing**. Instead, you can check for the existence of an element in the set.

# %% [markdown]
# ### 4.3 Modifying a Set

# %% [markdown]
# Sets in Python are mutable, meaning **you can add or remove elements** after the set has been created. However, due to their unordered nature and lack of indices, **direct editing of specific elements in a set is not possible**. If you want to update an element within a set, the common approach is to remove the existing element and then add the updated element as a new entry to the set.

# %% [markdown]
# #### Adding Elements to a Set

# %% [markdown]
# To add *a single element* to a set, use the **add()** method.

# %%
# Example
# Out:
# {'apple', 'avocado', 'banana', 'kiwi', 'orange', 'pineapple'}

# %% [markdown]
# #### Adding Multiple Elements to a Set

# %% [markdown]
# To add multiple elements to a set, use the **update()** method.

# %%
# Example
# Out:
# {'apple',
#  'avocado',
#  'banana',
#  'grapes',
#  'kiwi',
#  'orange',
#  'pineapple',
#  'watermelon'}

# %% [markdown]
# #### Removing Elements from a Set
# To remove an element from a set, use the **remove()** method.

# %%
# Example
# Out:
# {'apple', 'avocado', 'grapes', 'kiwi', 'orange', 'pineapple', 'watermelon'}

# %%
# Out:
# 'apple'

# %%
# Out:
# {'avocado', 'grapes', 'kiwi', 'orange', 'pineapple', 'watermelon'}

# %%
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
# Difference
# Out:
# {1}

# %%
# Difference_update

# %%
# Out:
# None

# %%
# Out:
# {2, 3, 4}

# %%
# intersection
# Out:
# set()

# %%
# Out:
# {1}

# %%
# Isdisjoint
# Out:
# True

# %%
# Out:
# {2, 3, 4}

# %%
# Out:
# {2, 5, 6}

# %%
# symmetric_difference
# Out:
# {3, 4, 5, 6}

# %%
# symmetric_difference update

# %% [markdown]
# # 5. Python Dictionaries: Understanding Key-Value Pairs

# %% [markdown]
# In Python, dictionaries are a fundamental data structure that allows you to store and retrieve data values **in key-value pairs**. Each key in a dictionary is unique and is associated with a specific value. **Dictionaries are mutable**, enabling you to modify, add, or remove key-value pairs dynamically.
#
# Dictionaries are denoted with **curly brackets {}** and consist of keys and their corresponding values. **Each key-value pair is separated by a colon (:)**.

# %% [markdown]
# ### 5.1 Creating a Dictionary

# %% [markdown]
# To create a dictionary, **use curly braces {}** and **separate key-value pairs with colons ":"**. Each key-value pair is **separated by commas**.

# %% [markdown]
# Alternatively, you can use the **dict()** constructor to create a dictionary.

# %%
# Syntax
my_dict = {key:value,key:value, key:value}

my_dict = dict(key1=value1, key2=value2, key3=value3, ...)

# %% [markdown]
# #### Examples of Dictionaries

# %% [markdown]
# **Important Note**: In a dictionary, the values can be of any data type, but there are specific rules for the keys. Firstly, each key can only appear once in a dictionary; duplicates are not allowed. Secondly, a dictionary key must belong to an immutable type (*like strings, integers, or tuples*), and it cannot be a mutable type such as a *list*.

# %%
# Example 1: Membership Information


# Example 2: Student Information

# Example 3: Book Information
# Out:
# {'member_id': 100, 'name': 'Christian Owusu', 'membership_level': 'Gold', 'expiration_date': '2024-12-31'}
# {'student_id': 10635, 'name': 'Kwabena Osei', 'age': 25, 'major': 'Computer Science'}

# %% [markdown]
# ### 5.2 Accessing Dictionary Elements

# %% [markdown]
# You can access the value associated with a specific key in a dictionary using **square brackets []**.

# %%
# Example 1 --- Using the Key
# Out:
# Christian Owusu
# Gold

# %%
# Example 2
# Out:
# Computer Science

# %% [markdown]
# ### 5.3 Modifying a Dictionary
#
# Dictionaries are mutable, so **you can modify, add, or remove key-value pairs**.

# %% [markdown]
# #### Modifying the Value of a Key

# %% [markdown]
# To modify the value associated with a key, **use the key within square brackets and assign a new value**.

# %%
# Example
# Out:
# {'student_id': 10635, 'name': 'Kwabena Osei', 'age': 25, 'major': 'Statistics'}

# %% [markdown]
# #### Adding a New Key-Value Pair

# %% [markdown]
# To add a new key-value pair, **assign a value to a new key** within square brackets.

# %%
# Example
# Out:
# {'student_id': 10635, 'name': 'Kwabena Osei', 'age': 25, 'major': 'Statistics', 'minor': 'Computer Science'}

# %% [markdown]
# #### Removing a Key-Value Pair

# %% [markdown]
# To remove a key-value pair, use the **pop()** method. This method requires you to specify the key of the pair you want to remove.

# %%
# Example
# Out:
# {'student_id': 10635, 'name': 'Kwabena Osei', 'major': 'Statistics', 'minor': 'Computer Science'}

# %%
# Out:
# {'student_id': 10635, 'name': 'Kwabena Osei', 'major': 'Statistics'}

# %%
# Out:
# {'student_id': 10635, 'name': 'Kwabena Osei'}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 student_info.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
# .popitem()
# del member_info['age']
# .clear()

# %%
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# ## 5.b Basic Dictionary Methods and Operations

# %% [markdown]
# Python provides a set of built-in methods and operations that can be used on dictionaries.

# %% [markdown]
# ### 5.4 Dictionary Methods

# %% [markdown]
#  Below are some commonly used dictionary methods:
#
#  - **clear()**: Removes all the elements from the dictionary.
#  - **copy()**: Returns a copy of the dictionary.
#  - **get()**: Returns the value of the specified key.
#  - **keys()**: Returns a list containing the dictionary's keys.

# %%
# Out:
# {}

# %%
# Out:
# {'member_id': 100, 'name': 'Christian Owusu', 'membership_level': 'Gold', 'expiration_date': '2024-12-31'}

# %%
# Out:
# Christian Owusu

# %%
# Out:
# dict_keys(['member_id', 'name', 'membership_level', 'expiration_date'])

# %%
# Out:
# dict_values([100, 'Christian Owusu', 'Gold', '2024-12-31'])

# %%
# original_dict = {"apple": 1, "banana": 2, "orange": 3, "avocado": 4, "pineapple": 5}


# Using copy()

# %%
# Using get()

# %%
# Using keys()

# %%
# Using values()

# %% [markdown]
# # 6. Practice Exercises

# %% [markdown]
# 1. Create a dictionary representing a library. Each book in the library should have an ISBN number as its key and a dictionary representing the book (with keys for 'title', 'author', and 'year') as its value.
#
# 2. Add a new book to the library dictionary and print out the updated library.
